# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('http://oxylabs.io/')
print(response.text)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><title>Oxylabs - High Quality Proxy Service to Gather Data at Scale</title><meta name="description" content="The best proxy service platform with 100M+ Residential and 2M Datacenter IP proxies. Extract public data from any website with ease!"/><meta property="og:title" content="Oxylabs - High Quality Proxy Service to Gather Data at Scale"/><meta property="og:description" content="The best proxy service platform with 100M+ Residential and 2M Datacenter IP proxies. Extract public data from any website with ease!"/><meta property="og:image" content="https://oxylabs.io/oxylabs-web/ZpAm1h5LeNNTxDSl_0e69ceb5-83ac-4bc6-862b-77474ebb7f40_oxylabs.png?auto=format,compress"/><meta property="og:type" content="website"/><meta name="twitter:image" content="https://oxylabs.io/oxylabs-web/ZpAm1h5LeNNTxDSl_0e69ceb5-83ac-4bc6-862b-77474ebb7f40_oxylabs.png?auto=format,compress"/><meta name="t
# ...
